# %%
from functions import cluster
# Out:
#             User authentication requires interaction with your
#             web browser. Once you enter your credentials and
#             give authorization, you will be redirected to
#             a url.  Paste that url you were directed to to
#             complete the authorization.
#
#
# Opened https://accounts.spotify.com/authorize?client_id=811e72eca79049a9a7fadf4fc8c0f299&response_type=code&redirect_uri=http%3A%2F%2Fgoogle.com%2F&scope=user-top-read in your browser
# Enter the URL you were redirected to:  https://www.google.com/?code=AQCCMvj020sh9zYzXjOVCfj_AOZPod4waHcPeGO-cmDo6Qf_zlRTCdpbNiwyCkVGjvrd3Ebp62YFs7KzlmzroPBMLE-kGxkGID_8o1HwqH5r3YJVUd71cO3I7PNBNgFvh1aa3yTN9tS0AzUw2_UO8PrNHbDL0pFQd1ktA_AHFmRkzF6SIM7clHXCv7RdDchBbDkmbeiw6Rty

# %%
data = cluster('tannerkoscinski', '7oG3OYCE79smeQ2IgqbT8a', 2, usesimple=True)

# %%
data
# Out:
#              artist              album                     track  \
# 0         Beartooth            Disease        Greatness or Death
# 1         Beartooth            Disease                   Disease
# 2         Beartooth            Disease                      Fire
# 3         Beartooth            Disease            You Never Know
# 4         Beartooth            Disease              Bad Listener
# 5         Beartooth            Disease                  Afterall
# 6         Beartooth            Disease              Manipulation
# 7         Beartooth            Disease                     Enemy
# 8         Beartooth            Disease                   Believe
# 9         Beartooth            Disease                 Infection
# 10        Beartooth            Disease           Used and Abused
# 11        Beartooth            Disease                    Clever
# 12        Beartooth         Aggressive                Aggressive
# ...
